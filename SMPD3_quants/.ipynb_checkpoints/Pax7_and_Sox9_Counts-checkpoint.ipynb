# %%
pwd
# Out:
# '/Users/michaelpiacentino/Drive/SMPD3_quants'

# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('smpd3_quants.csv')

# %%
df.head()
# Out:
#                         Experiment    Treatment (right/left)   Reagent  \
# 0  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 1  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 2  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 3  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 4  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
#
#       Dose  Embryo  Somites  HH Stage          File Name  Section  \
# 0  2 µg/µl       1        7         9  Emb1_7ss_sec1.czi        1
# 1  2 µg/µl       1        7         9  Emb1_7ss_sec2.czi        2
# 2  2 µg/µl       1        7         9  Emb1_7ss_sec3.czi        3
# 3  2 µg/µl       1        7         9  Emb1_7ss_sec4.czi        4
# 4  2 µg/µl       1        7         9  Emb1_7ss_sec5.czi        5
#
#    Cntl Pax7 Total Cells  Cntl Pax7 Tube Cells  Cntl Pax7 Mig Cells  \
# 0                     41                    18                   23
# 1                     47                    19                   28
# 2                     18                    12                    6
# 3                     57                    30                   27
# 4                     21                    13                    8
#
#    Expt Pax7 Total Cells  Expt Pax7 Tube Cells  Expt Pax7 Mig Cells  \
# 0                     28                    15                   13
# 1                     32                    18                   14
# 2                     17                    11                    6
# 3                     23                    14                    9
# 4                     18                    15                    3
#
#    Cntl Sox9 Cells  Expt Sox9 Cells
# 0               23               18
# 1               33               14
# 2               15                6
# 3               34               15
# 4               19               14

# %%
# hides all values that are not at HH stage 9, but does not remove them
mask = df['HH Stage'] != 9
df[~mask].head()
# Out:
#                         Experiment    Treatment (right/left)   Reagent  \
# 0  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 1  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 2  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 3  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 4  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
#
#       Dose  Embryo  Somites  HH Stage          File Name  Section  \
# 0  2 µg/µl       1        7         9  Emb1_7ss_sec1.czi        1
# 1  2 µg/µl       1        7         9  Emb1_7ss_sec2.czi        2
# 2  2 µg/µl       1        7         9  Emb1_7ss_sec3.czi        3
# 3  2 µg/µl       1        7         9  Emb1_7ss_sec4.czi        4
# 4  2 µg/µl       1        7         9  Emb1_7ss_sec5.czi        5
#
#    Cntl Pax7 Total Cells  Cntl Pax7 Tube Cells  Cntl Pax7 Mig Cells  \
# 0                     41                    18                   23
# 1                     47                    19                   28
# 2                     18                    12                    6
# 3                     57                    30                   27
# 4                     21                    13                    8
#
#    Expt Pax7 Total Cells  Expt Pax7 Tube Cells  Expt Pax7 Mig Cells  \
# 0                     28                    15                   13
# 1                     32                    18                   14
# 2                     17                    11                    6
# 3                     23                    14                    9
# 4                     18                    15                    3
#
#    Cntl Sox9 Cells  Expt Sox9 Cells
# 0               23               18
# 1               33               14
# 2               15                6
# 3               34               15
# 4               19               14

# %%
# retain only rows that are from stage 9 embryos
stage_9 = df[df['HH Stage'] == 9]
stage_9.head()
# Out:
#                         Experiment    Treatment (right/left)   Reagent  \
# 0  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 1  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 2  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 3  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
# 4  2017.10.16_SMPD3_gRNA1_Cas9eGFP  SMPD3 gRNA1/Control gRNA  Cas9eGFP
#
#       Dose  Embryo  Somites  HH Stage          File Name  Section  \
# 0  2 µg/µl       1        7         9  Emb1_7ss_sec1.czi        1
# 1  2 µg/µl       1        7         9  Emb1_7ss_sec2.czi        2
# 2  2 µg/µl       1        7         9  Emb1_7ss_sec3.czi        3
# 3  2 µg/µl       1        7         9  Emb1_7ss_sec4.czi        4
# 4  2 µg/µl       1        7         9  Emb1_7ss_sec5.czi        5
#
#    Cntl Pax7 Total Cells  Cntl Pax7 Tube Cells  Cntl Pax7 Mig Cells  \
# 0                     41                    18                   23
# 1                     47                    19                   28
# 2                     18                    12                    6
# 3                     57                    30                   27
# 4                     21                    13                    8
#
#    Expt Pax7 Total Cells  Expt Pax7 Tube Cells  Expt Pax7 Mig Cells  \
# 0                     28                    15                   13
# 1                     32                    18                   14
# 2                     17                    11                    6
# 3                     23                    14                    9
# 4                     18                    15                    3
#
#    Cntl Sox9 Cells  Expt Sox9 Cells
# 0               23               18
# 1               33               14
# 2               15                6
# 3               34               15
# 4               19               14

# %%
section_means = (stage_9.groupby(['Embryo'])
                ['Cntl Pax7 Total Cells', 'Expt Pax7 Total Cells', 
                 'Cntl Sox9 Cells', 'Expt Sox9 Cells'])
section_means_ratio = section_means.mean().reset_index()
section_means_ratio
# Out:
#    Embryo  Cntl Pax7 Total Cells  Expt Pax7 Total Cells  Cntl Sox9 Cells  \
# 0       1                   36.8                   23.6             24.8
# 1       2                   46.4                   48.0             23.8
# 2       3                   34.2                   32.4             24.8
# 3       5                   73.6                   52.0             41.2
# 4       6                   34.8                   46.8             26.0
# 5       7                   41.2                   37.6             21.8
# 6       9                   23.4                   32.4             14.2
#
#    Expt Sox9 Cells
# 0             13.4
# 1             21.2
# 2             27.6
# 3             28.4
# 4             37.8
# 5             22.6
# 6             14.2

# %%
section_means_ratio['Expt/Cntl Pax7'] = (section_means_ratio['Expt Pax7 Total Cells'] 
                                         / section_means_ratio['Cntl Pax7 Total Cells'])
section_means_ratio['Expt/Cntl Sox9'] = (section_means_ratio['Expt Sox9 Cells'] 
                                         / section_means_ratio['Cntl Sox9 Cells'])
section_means_ratio
# Out:
#    Embryo  Cntl Pax7 Total Cells  Expt Pax7 Total Cells  Cntl Sox9 Cells  \
# 0       1                   36.8                   23.6             24.8
# 1       2                   46.4                   48.0             23.8
# 2       3                   34.2                   32.4             24.8
# 3       5                   73.6                   52.0             41.2
# 4       6                   34.8                   46.8             26.0
# 5       7                   41.2                   37.6             21.8
# 6       9                   23.4                   32.4             14.2
#
#    Expt Sox9 Cells  Expt/Cntl Pax7  Expt/Cntl Sox9
# 0             13.4        0.641304        0.540323
# 1             21.2        1.034483        0.890756
# 2             27.6        0.947368        1.112903
# 3             28.4        0.706522        0.689320
# 4             37.8        1.344828        1.453846
# 5             22.6        0.912621        1.036697
# 6             14.2        1.384615        1.000000

# %%
alt.Chart(section_means_ratio,
    title='Normalized Cell Counts'
    ).mark_circle(
        color='blue'
    ).encode(
        x='Expt/Cntl Pax7:Q',
    )

#problem - I can't figure out how to plot Sox9 results as a separate dataset on the same plot
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
pax7 = alt.Chart(section_means_ratio,
        title='Norm. Pax7 Counts',
        height=50,
        width=250,
    ).mark_circle(
        size=50,
        opacity=0.9
    ).encode(     
        x=alt.X('Expt/Cntl Pax7:Q',
               title='Expt/Cntl')
    )

sox9 = alt.Chart(section_means_ratio,
    title='Norm. Sox9 Counts',
    height=50,
    width=250
    ).mark_circle(
        size=50,
        opacity=0.9
    ).encode(
        x=alt.X('Expt/Cntl Sox9:Q',
               title='Expt/Cntl')
    )

pax7 | sox9
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
section_means_ratio.to_csv('section_means_ratio.csv')

# %% [markdown]
# Goal: deal with section_means_ratio DataFrame to move the means around into a more tidy organization,
# then using those appraoches, improve tidiness of the bigger DataFrames
